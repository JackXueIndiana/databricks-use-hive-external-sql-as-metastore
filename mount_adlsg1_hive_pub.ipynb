# %% [markdown]
# ## This script is to show you how to connect Azure Databricks cluster to a HD Insight hive table which has its metadata stored in an Azure SQL Database.

# %%
# %fs
ls "/mnt/hive"
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/mnt/hive/HdiSamples/</td><td>HdiSamples/</td><td>0</td></tr><tr><td>dbfs:/mnt/hive/ams/</td><td>ams/</td><td>0</td></tr><tr><td>dbfs:/mnt/hive/amshbase/</td><td>amshbase/</td><td>0</td></tr><tr><td>dbfs:/mnt/hive/app-logs/</td><td>app-logs/</td><td>0</td></tr><tr><td>dbfs:/mnt/hive/apps/</td><td>apps/</td><td>0</td></tr><tr><td>dbfs:/mnt/hive/atshistory/</td><td>atshistory/</td><td>0</td></tr><tr><td>dbfs:/mnt/hive/custom-scriptaction-logs/</td><td>custom-scriptaction-logs/</td><td>0</td></tr><tr><td>dbfs:/mnt/hive/example/</td><td>example/</td><td>0</td></tr><tr><td>dbfs:/mnt/hive/hbase/</td><td>hbase/</td><td>0</td></tr><tr><td>dbfs:/mnt/hive/hdp/</td><td>hdp/</td><td>0</td></tr><tr><td>dbfs:/mnt/hive/hive/</td><td>hive/</td><td>0</td></tr><tr><td>dbfs:/mnt/hive/mapred/</td><td>mapred/</td><td>0</td></tr><tr><td>dbfs:/mnt/hive/mr-history/</td><td>mr-history/</td><td>0</td></tr><tr><td>dbfs:/mnt/hive/test/</td><td>test/</td><td>0</td></tr><tr><td>dbfs:/mnt/hive/tmp/</td><td>tmp/</td><td>0</td></tr><tr><td>dbfs:/mnt/hive/user/</td><td>user/</td><td>0</td></tr></tbody></table></div>

# %%
# %sql
show tables
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>default</td><td>hivesampletable</td><td>false</td></tr></tbody></table></div>

# %%
# %sql
show create table hivesampletable
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>createtab_stmt</th></tr></thead><tbody><tr><td>CREATE TABLE `hivesampletable`(`clientid` STRING, `querytime` STRING, `market` STRING, `deviceplatform` STRING, `devicemake` STRING, `devicemodel` STRING, `state` STRING, `country` STRING, `querydwelltime` DOUBLE, `sessionid` BIGINT, `sessionpagevieworder` BIGINT)
# ROW FORMAT SERDE 'org.apache.hadoop.hive.serde2.lazy.LazySimpleSerDe'
# WITH SERDEPROPERTIES (
#   'serialization.format' = '	',
#   'field.delim' = '	'
# )
# STORED AS
#   INPUTFORMAT 'org.apache.hadoop.mapred.TextInputFormat'
#   OUTPUTFORMAT 'org.apache.hadoop.hive.ql.io.HiveIgnoreKeyTextOutputFormat'
# TBLPROPERTIES (
#   'transient_lastDdlTime' = '1549595832'
# )
# </td></tr></tbody></table></div>

# %%
# %sql
select clientid from hivesampletable limit 10;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>clientid</th></tr></thead><tbody><tr><td>8</td></tr><tr><td>23</td></tr><tr><td>23</td></tr><tr><td>23</td></tr><tr><td>28</td></tr><tr><td>28</td></tr><tr><td>28</td></tr><tr><td>28</td></tr><tr><td>28</td></tr><tr><td>28</td></tr></tbody></table></div>

# %%
# %fs
ls "/mnt/hive/hive/warehouse"
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/mnt/hive/hive/warehouse/hivesampletable/</td><td>hivesampletable/</td><td>0</td></tr></tbody></table></div>
